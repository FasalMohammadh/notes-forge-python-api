# %%
! pip install simplet5 -q
from simplet5 import SimpleT5

model = SimpleT5()
model.load_model("t5","./simplet5-epoch-4-train-loss-1.9153-val-loss-1.8301", use_gpu=False)
text_to_summarize="""summarize: Vaccination and safety measures such as wearing face masks are essential when it comes to fighting the Delta Plus coronavirus variant, World Health Organization (WHO) representative to Russia Melita Vujnovic said.
"Vaccination plus masks, because just a vaccine is not enough with 'Delta Plus'. We need to make an effort over a short period of time, otherwise there would be a lockdown," Vujnovic said on the Soloviev Live YouTube show.
She explained that vaccination is essential because it lowers the probability of spreading the virus and lowers the risks of severe disease. However, "additional measures" will probably be required as well, Vujnovic warned.
Earlier in June, the WHO included the Delta variant in its list of coronavirus variants of concern as the strain had become prevalent and has caused a resurgence of COVID-19 cases in some countries, including Russia. India has also reported multiple cases of the Delta Plus strain, which was first discovered in March.
"""
model.predict(text_to_summarize)
# Out:
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# 404 Client Error: Not Found for url: https://huggingface.co//simplet5-epoch-4-train-loss-1.9153-val-loss-1.8301/resolve/main/config.json
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\configuration_utils.py:585, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     583 try:
#     584     # Load from URL or cache if already cached
# --> 585     resolved_config_file = cached_path(
#     586         config_file,
#     587         cache_dir=cache_dir,
#     588         force_download=force_download,
#     589         proxies=proxies,
#     590         resume_download=resume_download,
#     591         local_files_only=local_files_only,
#     592         use_auth_token=use_auth_token,
#     593         user_agent=user_agent,
#     594     )
#     596 except RepositoryNotFoundError as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\file_utils.py:1846, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1844 if is_remote_url(url_or_filename):
#    1845     # URL, so get it from the cache (downloading if necessary)
# -> 1846     output_path = get_from_cache(
#    1847         url_or_filename,
#    1848         cache_dir=cache_dir,
#    1849         force_download=force_download,
#    1850         proxies=proxies,
#    1851         resume_download=resume_download,
#    1852         user_agent=user_agent,
#    1853         use_auth_token=use_auth_token,
#    1854         local_files_only=local_files_only,
#    1855     )
#    1856 elif os.path.exists(url_or_filename):
#    1857     # File, and it exists.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\file_utils.py:2050, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    2049 r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
# -> 2050 _raise_for_status(r)
#    2051 etag = r.headers.get("X-Linked-Etag") or r.headers.get("ETag")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\file_utils.py:1977, in _raise_for_status(request)
#    1975         raise RevisionNotFoundError((f"404 Client Error: Revision Not Found for url: {request.url}"))
# -> 1977 request.raise_for_status()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co//simplet5-epoch-4-train-loss-1.9153-val-loss-1.8301/resolve/main/config.json
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 5
#       2 from simplet5 import SimpleT5
#       4 model = SimpleT5()
# ----> 5 model.load_model("t5","/simplet5-epoch-4-train-loss-1.9153-val-loss-1.8301", use_gpu=False)
#       6 text_to_summarize="""summarize: Vaccination and safety measures such as wearing face masks are essential when it comes to fighting the Delta Plus coronavirus variant, World Health Organization (WHO) representative to Russia Melita Vujnovic said.
#       7 "Vaccination plus masks, because just a vaccine is not enough with 'Delta Plus'. We need to make an effort over a short period of time, otherwise there would be a lockdown," Vujnovic said on the Soloviev Live YouTube show.
#       8 She explained that vaccination is essential because it lowers the probability of spreading the virus and lowers the risks of severe disease. However, "additional measures" will probably be required as well, Vujnovic warned.
#       9 Earlier in June, the WHO included the Delta variant in its list of coronavirus variants of concern as the strain had become prevalent and has caused a resurgence of COVID-19 cases in some countries, including Russia. India has also reported multiple cases of the Delta Plus strain, which was first discovered in March.
#      10 """
#      11 model.predict(text_to_summarize)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\simplet5\simplet5.py:408, in SimpleT5.load_model(self, model_type, model_dir, use_gpu)
#     400 """
#     401 loads a checkpoint for inferencing/prediction
#     402 Args:
#    (...)
#     405     use_gpu (bool, optional): if True, model uses gpu for inferencing/prediction. Defaults to True.
#     406 """
#     407 if model_type == "t5":
# --> 408     self.model = T5ForConditionalGeneration.from_pretrained(f"{model_dir}")
#     409     self.tokenizer = T5Tokenizer.from_pretrained(f"{model_dir}")
#     410 elif model_type == "mt5":
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:1268, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1266 if not isinstance(config, PretrainedConfig):
#    1267     config_path = config if config is not None else pretrained_model_name_or_path
# -> 1268     config, model_kwargs = cls.config_class.from_pretrained(
#    1269         config_path,
#    1270         cache_dir=cache_dir,
#    1271         return_unused_kwargs=True,
#    1272         force_download=force_download,
#    1273         resume_download=resume_download,
#    1274         proxies=proxies,
#    1275         local_files_only=local_files_only,
#    1276         use_auth_token=use_auth_token,
#    1277         revision=revision,
#    1278         _from_auto=from_auto_class,
#    1279         _from_pipeline=from_pipeline,
#    1280         **kwargs,
#    1281     )
#    1282 else:
#    1283     model_kwargs = kwargs
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\configuration_utils.py:510, in PretrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     436 @classmethod
#     437 def from_pretrained(cls, pretrained_model_name_or_path: Union[str, os.PathLike], **kwargs) -> "PretrainedConfig":
#     438     r"""
#     439     Instantiate a [`PretrainedConfig`] (or a derived class) from a pretrained model configuration.
#     440
#    (...)
#     508     assert unused_kwargs == {"foo": False}
#     509     ```"""
# --> 510     config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     511     if "model_type" in config_dict and hasattr(cls, "model_type") and config_dict["model_type"] != cls.model_type:
#     512         logger.warn(
#     513             f"You are using a model of type {config_dict['model_type']} to instantiate a model of type "
#     514             f"{cls.model_type}. This is not supported for all configurations of models and can yield errors."
#     515         )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\configuration_utils.py:537, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     535 original_kwargs = copy.deepcopy(kwargs)
#     536 # Get config dict associated with the base config file
# --> 537 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     539 # That config file may point us toward another config file to use.
#     540 if "configuration_files" in config_dict:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\configuration_utils.py:618, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     616 except HTTPError as err:
#     617     logger.error(err)
# --> 618     raise EnvironmentError(
#     619         "We couldn't connect to 'https://huggingface.co/' to load this model and it looks like "
#     620         f"{pretrained_model_name_or_path} is not the path to a directory conaining a {configuration_file} "
#     621         "file.\nCheckout your internet connection or see how to run the library in offline mode at "
#     622         "'https://huggingface.co/docs/transformers/installation#offline-mode'."
#     623     )
#     624 except EnvironmentError as err:
#     625     logger.error(err)
#
# OSError: We couldn't connect to 'https://huggingface.co/' to load this model and it looks like /simplet5-epoch-4-train-loss-1.9153-val-loss-1.8301 is not the path to a directory conaining a config.json file.
# Checkout your internet connection or see how to run the library in offline mode at 'https://huggingface.co/docs/transformers/installation#offline-mode'.
